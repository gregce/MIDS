# %% [markdown]
# # IMDBY movie analysis
# Predicting IMDB Movie Ratings: Using social media data and open source tools
# W205 - Greg, Talieh, Apekshit

# %% [markdown]
# #### First connect to hive and get sentiment analysis data

# %%
import pyhs2
import pandas as pd
import statsmodels as sm
import imdb
import statsmodels.formula.api as smf
import re

with pyhs2.connect(host='52.23.237.143',
               port=10000,
               authMechanism="PLAIN",
               user='root',
               database='default') as conn:
    with conn.cursor() as cur:
        #Show databases
        #print cur.getDatabases()
        
        cur.execute("select title as title \
                        ,   production_year as production_year \
                       ,    se_ratio as se_ratio from cp_finalresults_temp")
        
        #Return column info from query
        schema =  cur.getSchema()
        records = cur.fetchall()
    
        cols = []
        for i in range(0,len(schema)):
             cols.append(schema[i].values()[1])
                
## Create Dataframe        
movies_temp=pd.DataFrame(records,columns=cols)
movies_temp
# Out:
#                      title production_year  se_ratio
# 0                 45 Years            2015  0.638695
# 1                      Amy            2015  0.333125
# 2                Anomalisa            2015  0.648936
# 3      Beasts of No Nation            2015  0.439338
# 4                  Breathe            2015  0.297600
# 5          Bridge of Spies            2015  0.472897
# 6                 Brooklyn            2015  0.160243
# 7                    Carol            2015  0.577378
# 8              Cartel Land            2015  0.622642
# 9               Cinderella            2015  0.548825
# 10             Coming Home            2015  0.208647
# 11                   Creed            2015  0.189662
# 12                    Dope            2015  0.201000
# 13              Ex Machina            2015  0.356215
# 14            Experimenter            2015  0.372922
# 15                 Grandma            2015  0.356669
# 16          Heart of a Dog            2015  0.714286
# 17              Inside Out            2015  0.535456
# 18                    Iris            2015  0.528886
# 19             James White            2015  0.112648
# 20                    Meru            2015  0.427536
# 21       Mississippi Grind            2015  0.368421
# 22                   Mommy            2015  0.177513
# 23          Monkey Kingdom            2015  0.200000
# 24                 Phoenix            2015  0.253436
# 25          Queen of Earth            2015  0.545455
# 26                    Room            2015  0.302625
# 27                 Sicario            2015  0.414173
# 28               Slow West            2015  0.448276
# 29               Spotlight            2015  0.753293
# 30                  Spring            2015  0.389429
# 31                     Spy            2015  0.271602
# 32              Steve Jobs            2015  0.450148
# 33  Straight Outta Compton            2015  0.492674
# 34               Tangerine            2015  0.482792
# 35      The Forbidden Room            2015  0.356164
# 36                The Gift            2015  0.352830
# 37      The Hunting Ground            2015  0.613636
# 38             The Lobster            2015  0.278351
# 39             The Martian            2015  0.300175
# 40       The Peanuts Movie            2015  0.406489
# 41               The Tribe            2015  0.275862
# 42                The Walk            2015  0.438710
# 43              Trainwreck            2015  0.282416
# 44               Turbo Kid            2015  0.471519

# %% [markdown]
# ## Gather current movie_attributes using IMDbPy

# %%
# Import the imdb package.
import imdb

# Create the object that will be used to access the IMDb's database.
ia = imdb.IMDb() # by default access the web.

movie_attributes = pd.DataFrame()

for index, row in movies_temp.iterrows():
    s_result = ia.search_movie(row['title'])
    movie = s_result[0]
    ia.update(movie)
    join_title = pd.Series(row['title'])
    imdb_title = pd.Series(movie['title'])
    ## get first element in list
    genre = pd.Series((movie['genre'][0]))
    rating = pd.Series(movie['rating'])
    votes = pd.Series(movie['votes'])
    runtime = pd.Series(movie['runtime'])
    language = pd.Series(movie['language'])
    director = re.search(r"Name:\s(.*)", movie['director'][0].summary()).group(1)
    producer = re.search(r"Name:\s(.*)", movie['produced by'][0].summary()).group(1)
    
    temp = pd.DataFrame({'join_title':join_title
                 ,'imdb_title':imdb_title
                 ,'imdb_rating':rating
                 ,'genre':genre
                 ,'imdb_votes':votes
                 ,'language':language
                 ,'runtime':runtime
                 ,'director':director
                 ,'producer':producer  
                        })
    
    movie_attributes = movie_attributes.append(temp)
                                 
movie_attributes.ix[0]
# Out:
#                   director        genre  imdb_rating              imdb_title  \
# 0            Haigh, Andrew        Drama          7.5                45 Years
# 0            Kapadia, Asif  Documentary          7.9                     Amy
# 0            Johnson, Duke    Animation          8.1               Anomalisa
# 0      Fukunaga, Cary Joji        Drama          7.9     Beasts of No Nation
# 0           Passon, Stacie        Drama          5.7              Concussion
# 0        Spielberg, Steven    Biography          7.9         Bridge of Spies
# 0            Crowley, John        Drama          8.1                Brooklyn
# 0             Haynes, Todd        Drama          7.8                   Carol
# 0        Heineman, Matthew  Documentary          7.4             Cartel Land
# 0         Branagh, Kenneth        Drama          7.1              Cinderella
# 0               Ashby, Hal        Drama          7.3             Coming Home
# 0            Coogler, Ryan        Drama          8.6                   Creed
# 0           Famuyiwa, Rick       Comedy          7.3                    Dope
# 0            Garland, Alex        Drama          7.7              Ex Machina
# 0       Almereyda, Michael    Biography          6.7            Experimenter
# 0              Weitz, Paul       Comedy          7.1                 Grandma
# 0         Anderson, Laurie  Documentary          7.4          Heart of a Dog
# 0             Docter, Pete    Animation          8.4              Inside Out
# 0          Maysles, Albert  Documentary          7.0                    Iris
# 0               Mond, Josh        Drama          7.5             James White
# 0              Chin, Jimmy  Documentary          7.8                    Meru
# 0              Boden, Anna        Drama          6.4       Mississippi Grind
# 0            Dolan, Xavier        Drama          8.1                   Mommy
# 0           Linfield, Mark  Documentary          7.3          Monkey Kingdom
# 0       Petzold, Christian        Drama          7.3                 Phoenix
# 0         Perry, Alex Ross        Drama          6.8          Queen of Earth
# 0        Abrahamson, Lenny        Drama          8.3                    Room
# 0        Villeneuve, Denis       Action          8.0                 Sicario
# 0            Maclean, John       Action          7.0               Slow West
# 0            McCarthy, Tom    Biography          8.6               Spotlight
# 0           Benson, Justin       Horror          6.6                  Spring
# 0               Feig, Paul       Action          7.1                     Spy
# 0             Boyle, Danny    Biography          7.7              Steve Jobs
# 0            Gray, F. Gary    Biography          8.1  Straight Outta Compton
# 0              Baker, Sean       Comedy          7.0               Tangerine
# 0              Maddin, Guy       Comedy          7.0      The Forbidden Room
# 0           Edgerton, Joel      Mystery          7.2                The Gift
# 0              Dick, Kirby  Documentary          6.7      The Hunting Ground
# 0        Lanthimos, Yorgos       Comedy          7.7             The Lobster
# 0            Scott, Ridley    Adventure          8.2             The Martian
# 0           Martino, Steve    Animation          7.8       The Peanuts Movie
# 0  Slaboshpitsky, Miroslav        Crime          7.3                  Plemya
# 0         Zemeckis, Robert    Adventure          7.6                The Walk
# 0             Apatow, Judd       Comedy          6.5              Trainwreck
# 0         Simard, François       Action          6.6               Turbo Kid
#
#    imdb_votes              join_title               language  \
# 0        2110                45 Years                English
# 0       13450                     Amy                English
# 0        1090               Anomalisa                English
# 0       20128     Beasts of No Nation                English
# 0        2603                 Breathe                English
# 0       34777         Bridge of Spies                English
# 0        5057                Brooklyn                English
# 0        4743                   Carol                English
# 0        2755             Cartel Land                English
# 0       82026              Cinderella                English
# 0        8934             Coming Home                English
# 0       18205                   Creed                English
# 0       29227                    Dope                English
# 0      198351              Ex Machina                English
# 0        2459            Experimenter                English
# 0        1551                 Grandma                English
# 0         188          Heart of a Dog                English
# 0      212290              Inside Out                English
# 0        1429                    Iris                English
# 0         458             James White                English
# 0        2093                    Meru                English
# 0        4430       Mississippi Grind                English
# 0       21631                   Mommy                 French
# 0        1771          Monkey Kingdom                English
# 0        5788                 Phoenix                 German
# 0        1377          Queen of Earth                English
# 0        3960                    Room                English
# 0       46969                 Sicario                English
# 0       17888               Slow West                English
# 0        6985               Spotlight                English
# 0       10785                  Spring                English
# 0      120959                     Spy                English
# 0       15513              Steve Jobs                English
# 0       56866  Straight Outta Compton                English
# 0        3725               Tangerine                English
# 0         538      The Forbidden Room                English
# 0       46063                The Gift                English
# 0         884      The Hunting Ground                English
# 0        9179             The Lobster                English
# 0      187881             The Martian                English
# 0        5889       The Peanuts Movie                English
# 0        4557               The Tribe  Russian Sign Language
# 0       24790                The Walk                English
# 0       55305              Trainwreck                English
# 0        9595               Turbo Kid                English
#
#                          producer runtime
# 0                Dargavel, Rachel      95
# 0                      Bell, Paul     128
# 0                   Calder, Keith      90
# 0                Asomugha, Nnamdi     137
# 0                 Chenfeld, Cliff      96
# 0               Fisser, Christoph     141
# 0                   Dwyer, Finola     111
# 0                 Berwin, Dorothy     118
# 0                Bigelow, Kathryn     100
# 0                   Barron, David     105
# 0                  Gilbert, Bruce     127
# 0                Chartoff, Robert     133
# 0             Bongiovi, Nina Yang     103
# 0                       Bush, Eli     108
# 0             Abeckaser, Danny A.      98
# 0                   Balgoyen, Dan      79
# 0                Anderson, Laurie      75
# 0                  Lasseter, John      95
# 0            Rudick, Jennifer Ash      79
# 0                Balchan, Michael      85
# 0                     Chin, Jimmy      87
# 0                 Emmett, Randall     108
# 0                Corbeil, Sylvain     139
# 0            Fothergill, Alastair      81
# 0               Gaczkowski, Jacek      98
# 0  Konstantakopoulos, Christos V.      90
# 0                    Arkuss, Jeff     118
# 0                   Iwanyk, Basil     121
# 0               Butler, Katherine      84
# 0               Bederman, Michael     128
# 0                  Benson, Justin     109
# 0                  Chernin, Peter     119
# 0                 Bellew, Bernard     122
# 0                   Alvarez, Matt     147
# 0                     Baker, Sean      88
# 0              Barneville, Pascal     130
# 0                     Blum, Jason     108
# 0                     Blavin, Amy     103
# 0                   Collins, Cait     118
# 0                    Huffam, Mark     144
# 0                      Feig, Paul  USA:88
# 0         Slaboshpitsky, Miroslav     126
# 0              Martin, Cherylanne     123
# 0                    Apatow, Judd     125
# 0                Beaulieu, Benoit      93

# %% [markdown]
# ## Create Datasets for Analysis

# %%
## Merge Everything Together
cp_results = pd.merge(left=movies_temp,right=movie_attributes.ix[0], left_on='title', right_on='join_title')

#cleanup runtime
cp_results['runtime'] = cp_results['runtime'].str.replace(r'[^0-9]', '')
cp_results['runtime'] = cp_results['runtime'].astype(float)

## Create a training Set 
train = cp_results.sample(frac=0.5, random_state=1)

##Create a test set
test = cp_results.loc[~cp_results.index.isin(train.index)]

# %% [markdown]
# ## Fit Model

# %%
# a utility function to only show the coeff section of summary
from IPython.core.display import HTML
def short_summary(est):
    return HTML(est.summary().tables[1].as_html())

# fit OLS on a bunch of variables 
est = smf.ols(formula="imdb_rating ~ se_ratio + imdb_votes + runtime + C(language) + C(genre)", data=train).fit()
short_summary(est)
# Out:
# <table class="simpletable">
# <tr>
#                     <td></td>                      <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th> <th>[95.0% Conf. Int.]</th>
# </tr>
# <tr>
#   <th>Intercept</th>                            <td>    4.6203</td> <td>    1.219</td> <td>    3.789</td> <td> 0.005</td> <td>    1.808     7.432</td>
# </tr>
# <tr>
#   <th>C(language)[T.French]</th>                <td>    0.7670</td> <td>    0.818</td> <td>    0.937</td> <td> 0.376</td> <td>   -1.120     2.654</td>
# </tr>
# <tr>
#   <th>C(language)[T.German]</th>                <td>    0.5805</td> <td>    0.740</td> <td>    0.784</td> <td> 0.456</td> <td>   -1.127     2.288</td>
# </tr>
# <tr>
#   <th>C(language)[T.Russian Sign Language]</th> <td>    0.1701</td> <td>    0.460</td> <td>    0.370</td> <td> 0.721</td> <td>   -0.890     1.231</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Adventure]</th>                <td>    0.5811</td> <td>    0.963</td> <td>    0.604</td> <td> 0.563</td> <td>   -1.639     2.802</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Animation]</th>                <td>    1.3111</td> <td>    0.694</td> <td>    1.890</td> <td> 0.095</td> <td>   -0.288     2.910</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Biography]</th>                <td>    0.5677</td> <td>    0.659</td> <td>    0.862</td> <td> 0.414</td> <td>   -0.952     2.087</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Comedy]</th>                   <td>    0.1687</td> <td>    0.708</td> <td>    0.238</td> <td> 0.818</td> <td>   -1.463     1.800</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Crime]</th>                    <td>    0.1701</td> <td>    0.460</td> <td>    0.370</td> <td> 0.721</td> <td>   -0.890     1.231</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Documentary]</th>              <td>    1.1541</td> <td>    0.896</td> <td>    1.288</td> <td> 0.234</td> <td>   -0.911     3.220</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Drama]</th>                    <td>    0.2345</td> <td>    0.629</td> <td>    0.373</td> <td> 0.719</td> <td>   -1.217     1.686</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Horror]</th>                   <td>   -0.2157</td> <td>    0.841</td> <td>   -0.257</td> <td> 0.804</td> <td>   -2.155     1.724</td>
# </tr>
# <tr>
#   <th>C(genre)[T.Mystery]</th>                  <td>    0.3732</td> <td>    0.819</td> <td>    0.456</td> <td> 0.661</td> <td>   -1.516     2.262</td>
# </tr>
# <tr>
#   <th>se_ratio</th>                             <td>    1.0537</td> <td>    1.523</td> <td>    0.692</td> <td> 0.509</td> <td>   -2.458     4.566</td>
# </tr>
# <tr>
#   <th>imdb_votes</th>                           <td> 1.866e-06</td> <td> 3.69e-06</td> <td>    0.505</td> <td> 0.627</td> <td>-6.65e-06  1.04e-05</td>
# </tr>
# <tr>
#   <th>runtime</th>                              <td>    0.0162</td> <td>    0.011</td> <td>    1.465</td> <td> 0.181</td> <td>   -0.009     0.042</td>
# </tr>
# </table>

# %%
est.params
# Out:
# Intercept                               4.620270
# C(language)[T.French]                   0.767006
# C(language)[T.German]                   0.580477
# C(language)[T.Russian Sign Language]    0.170130
# C(genre)[T.Adventure]                   0.581142
# C(genre)[T.Animation]                   1.311068
# C(genre)[T.Biography]                   0.567684
# C(genre)[T.Comedy]                      0.168744
# C(genre)[T.Crime]                       0.170130
# C(genre)[T.Documentary]                 1.154071
# C(genre)[T.Drama]                       0.234517
# C(genre)[T.Horror]                     -0.215739
# C(genre)[T.Mystery]                     0.373197
# se_ratio                                1.053653
# imdb_votes                              0.000002
# runtime                                 0.016193
# dtype: float64

# %%
#est.predict(exog=dict(se_ratio=test['se_ratio'],imdb_votes=test['imdb_votes'],language=C(test['language'])))
predicted_values = est.predict(test[['se_ratio','imdb_votes','runtime','language','genre']])

##create a df to join back to test
predicted_imdb = pd.DataFrame({'predicted_imdb':predicted_values.tolist()})

test = test.reset_index()

#update test, rename as cp_final_results
cp_finalresults = pd.merge(left=test,right=predicted_imdb,left_index=True,right_index=True)

# %%
#test = test.reset_index()
cp_finalresults = pd.merge(left=test,right=predicted_imdb,left_index=True,right_index=True)
cp_finalresults = cp_finalresults.ix[:,2:15]
cp_finalresults
# Out:
#                  title production_year  se_ratio           director  \
# 0             45 Years            2015  0.638695      Haigh, Andrew
# 1                  Amy            2015  0.333125      Kapadia, Asif
# 2      Bridge of Spies            2015  0.472897  Spielberg, Steven
# 3             Brooklyn            2015  0.160243      Crowley, John
# 4                Carol            2015  0.577378       Haynes, Todd
# 5          Cartel Land            2015  0.622642  Heineman, Matthew
# 6           Cinderella            2015  0.548825   Branagh, Kenneth
# 7                Creed            2015  0.189662      Coogler, Ryan
# 8                 Dope            2015  0.201000     Famuyiwa, Rick
# 9           Ex Machina            2015  0.356215      Garland, Alex
# 10             Grandma            2015  0.356669        Weitz, Paul
# 11      Heart of a Dog            2015  0.714286   Anderson, Laurie
# 12                Iris            2015  0.528886    Maysles, Albert
# 13                Meru            2015  0.427536        Chin, Jimmy
# 14      Queen of Earth            2015  0.545455   Perry, Alex Ross
# 15                Room            2015  0.302625  Abrahamson, Lenny
# 16             Sicario            2015  0.414173  Villeneuve, Denis
# 17           Slow West            2015  0.448276      Maclean, John
# 18  The Hunting Ground            2015  0.613636        Dick, Kirby
# 19         The Lobster            2015  0.278351  Lanthimos, Yorgos
# 20            The Walk            2015  0.438710   Zemeckis, Robert
# 21          Trainwreck            2015  0.282416       Apatow, Judd
#
#           genre  imdb_rating          imdb_title  imdb_votes  \
# 0         Drama          7.5            45 Years        2110
# 1   Documentary          7.9                 Amy       13450
# 2     Biography          7.9     Bridge of Spies       34777
# 3         Drama          8.1            Brooklyn        5057
# 4         Drama          7.8               Carol        4743
# 5   Documentary          7.4         Cartel Land        2755
# 6         Drama          7.1          Cinderella       82026
# 7         Drama          8.6               Creed       18205
# 8        Comedy          7.3                Dope       29227
# 9         Drama          7.7          Ex Machina      198351
# 10       Comedy          7.1             Grandma        1551
# 11  Documentary          7.4      Heart of a Dog         188
# 12  Documentary          7.0                Iris        1429
# 13  Documentary          7.8                Meru        2093
# 14        Drama          6.8      Queen of Earth        1377
# 15        Drama          8.3                Room        3960
# 16       Action          8.0             Sicario       46969
# 17       Action          7.0           Slow West       17888
# 18  Documentary          6.7  The Hunting Ground         884
# 19       Comedy          7.7         The Lobster        9179
# 20    Adventure          7.6            The Walk       24790
# 21       Comedy          6.5          Trainwreck       55305
#
#             join_title language                        producer  runtime  \
# 0             45 Years  English                Dargavel, Rachel       95
# 1                  Amy  English                      Bell, Paul      128
# 2      Bridge of Spies  English               Fisser, Christoph      141
# 3             Brooklyn  English                   Dwyer, Finola      111
# 4                Carol  English                 Berwin, Dorothy      118
# 5          Cartel Land  English                Bigelow, Kathryn      100
# 6           Cinderella  English                   Barron, David      105
# 7                Creed  English                Chartoff, Robert      133
# 8                 Dope  English             Bongiovi, Nina Yang      103
# 9           Ex Machina  English                       Bush, Eli      108
# 10             Grandma  English                   Balgoyen, Dan       79
# 11      Heart of a Dog  English                Anderson, Laurie       75
# 12                Iris  English            Rudick, Jennifer Ash       79
# 13                Meru  English                     Chin, Jimmy       87
# 14      Queen of Earth  English  Konstantakopoulos, Christos V.       90
# 15                Room  English                    Arkuss, Jeff      118
# 16             Sicario  English                   Iwanyk, Basil      121
# 17           Slow West  English               Butler, Katherine       84
# 18  The Hunting Ground  English                     Blavin, Amy      103
# 19         The Lobster  English                   Collins, Cait      118
# 20            The Walk  English              Martin, Cherylanne      123
# 21          Trainwreck  English                    Apatow, Judd      125
#
#     predicted_imdb
# 0         7.070011
# 1         8.223123
# 2         8.034305
# 3         6.830473
# 4         7.382753
# 5         8.054818
# 6         7.286349
# 7         7.242245
# 8         6.723195
# 9         7.349012
# 10        6.446951
# 11        7.741768
# 12        7.613508
# 13        7.637502
# 14        6.889436
# 15        7.091798
# 16        7.103635
# 17        6.486174
# 18        8.090418
# 19        7.010185
# 20        7.701636
# 21        7.213877

# %% [markdown]
# ## Write Data Back to Hive

# %%
import pydoop.hdfs as hdfs
#hdfs.mkdir("/root/persist/data/cp_imdb_db/final_results/")

cp_finalresults.to_csv("/root/persist/data/imdb_csvs/cp_finalresults.csv", sep=',', na_rep='', header=True, index=False)
#hdfs.put("/root/persist/data/imdb_csvs/cp_finalresults.csv","/root/persist/data/cp_imdb_db/final_results/")

#cp_results.to_csv("/root/persist/data/imdb_csvs/cp_results.csv", sep=',', na_rep='', header=True, index=False)

#hdfs.put("/root/persist/data/imdb_csvs/cp_finalresults.csv","/root/persist/data/cp_imdb_db/final_results/")

#from pyhive import presto
#from pyhive import hive

#from sqlalchemy import *
#from sqlalchemy.engine import create_engine
#from sqlalchemy.schema import *

#engine = create_engine('presto://52.23.237.143:10000/hive/default')

#cp_finalresults.to_sql('cp_finalresults', engine, if_exists='replace', index=False)


#from pyhive import presto
#from pyhive import hive
#from sqlalchemy import *
#from sqlalchemy.engine import create_engine
#from sqlalchemy.schema import *
#conn = hive.Connection(host="52.23.237.143", port=10000, username="root", database="default")
#engine = create_engine('presto://localhost:10000/hive/default')
#cp_finalresults.to_sql('cp_finalresults', engine, if_exists='replace', index=False)
